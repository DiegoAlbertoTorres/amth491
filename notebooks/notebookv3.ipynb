# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import scipy.optimize as optimize 
import scipy.fftpack as fftpack
import scipy.signal as signal 
import scipy.interpolate as interpolate
import types
import lmfit

# import mpmath

pylab.rcParams['figure.figsize'] = (15.0, 3.0)
pylab.rcParams['axes.facecolor'] = 'lightgray'
np.set_printoptions(precision=15)

# %% [markdown]
# # Helper functions

# %%
def gauss(x, mu, sigma, amplitude): 
    return amplitude * np.exp( - ((x - mu) ** 2) / (2 * (sigma**2) ))

def per_gauss(wl, sigma, minWl, maxWl, period, amplitude):
    result = 0.0;
    current = minWl
    i = 0
    while current <= maxWl:
        result += gauss(wl, minWl + (i * period), sigma, amplitude)
        current += period
        i = i + 1
    return result

# %% [markdown]
# # Classes that define simulated instruments.

# %%
class Spectrograph:
    def __init__(self, xres, nOrders, orderSize, minWl, bgrNoiseMu, bgrNoiseSD, fwhm, precision):
        self.xres = xres
        self.nOrders = nOrders
        self.orderSize = orderSize
        self.bgrNoiseMu = bgrNoiseMu
        self.bgrNoiseSD = bgrNoiseSD
        self.minWl = minWl
        self.maxWl = minWl + orderSize * nOrders
        self.sigma = fwhm / (2 * np.sqrt(2 * np.log(2))) # sd = fhwm / 2sqrt(2ln2)
        self.precision = precision
        self.fac = self.xres / self.orderSize # Constantly used in conversions
    # A spectrograph can observe many beams: a beam is a mapping of wavelength (in nm) to intensity
    def observe(self, beams):
        space = np.empty((self.nOrders, 2,))
        observation = np.empty((self.nOrders, self.xres,))
        
        for i in range(0, self.nOrders):
            startWl = self.minWl + (i * self.orderSize)
            endWl = startWl + self.orderSize
            order_space = np.linspace(startWl, endWl, self.xres, endpoint=False)
            order_obs = np.zeros(len(order_space))

            bgrNoise = np.random.normal(self.bgrNoiseMu, self.bgrNoiseSD, len(order_space)) # Background noise
            bgrNoise[bgrNoise < 0.0] = 0.0001
            order_obs += bgrNoise

            # Each mapping in a beam becomes a gaussian
            for beam in beams:
                for wl in beam:
                    order_obs += gauss(order_space, wl, self.sigma, beam[wl])

            # Add shot noise
            order_obs += np.random.normal(0.0, np.sqrt(order_obs) * self.precision / 2, len(order_space))
            
#             plt.scatter(order_space, order_obs)
#             plt.show()
            
            order_map[i] = np.asarray([startWl, endWl])
            observation[i] = order_obs

        return space, observation
    
    def pix_to_wl(self, pix):
        return self.minWl + (pix / self.fac)
        
    def wl_to_pix(self, wl):
        return (wl - sgraph.minWl) * self.fac
        
class LFC:
    def __init__(self, intensity, minWl, maxWl, dWl):
        self.intensity = intensity
        self.minWl = minWl
        self.maxWl = maxWl
        self.span = self.maxWl - self.minWl
        self.dWl = np.float64(dWl)
    def getPeaks(self):
        peaks = np.empty(0)
        current = self.minWl;
        while(current <= self.maxWl):
            peaks = np.append(peaks, current)
            current += self.dWl
        return peaks
    def simulate(self):
        sim = {}
        current = self.minWl
        while current <= self.maxWl:
            sim[current] = self.intensity
            current += self.dWl
        return sim

# %%
# sgraph = Spectrograph(4000, 80, 10.0, 399.0, 1000.0, 300.0, 0.0075, 1.0)
# lfc = LFC(250000, 400, sgraph.maxWl - 1, 0.03)
# order_map, y = sgraph.observe([lfc.simulate()])
# print(order_map)
# print(y)

# %% [markdown]
# # Finding maxima

# %%
def plot_spectrum(ss_xs, ss_ys, y_preds, guess_x, fac, sol):
    for i in range(0, len(ss_xs)):
        plt.scatter(ss_xs[i], ss_ys[i], color='magenta')
        plt.plot(ss_xs[i], y_preds[i])
#         plt.scatter(ss_x, ss_obs[i], color='blue')
#         plt.plot(ss_x, pred_obs, color='red')
#         for peak in pred_peaks:
#             plt.axvline((peak - sgraph.minWl) * sgraph.fac, color='green')
#         for peak in lfc_peaks:
#             plt.axvline((peak - sgraph.minWl) * sgraph.fac, color='purple')
#         plt.axvline(guess_x, color='turquoise')
        if i == 0:
#             plt.xlim(sgraph.wl_to_pix(lfc.minWl - 3 * lfc.dWl), sgraph.wl_to_pix(lfc.minWl + 12 * lfc.dWl))
#             plt.xlim(sgraph.wl_to_pix(lfc.minWl - 3 * lfc.dWl), sgraph.wl_to_pix(lfc.minWl - 3 * lfc.dWl) + 50)
            plt.xlim(guess_x - 3 * lfc.dWl * fac, guess_x + 12 * lfc.dWl * fac)
            plt.axvline(guess_x, color='turquoise')
            plt.axvline(sol, color='purple')
        elif i == 1:
            plt.xlim(4100, 4150)
#             plt.xlim(sgraph.wl_to_pix(400), sgraph.wl_to_pix(401))
        plt.show()
#         plt.savefig('lol{}.png'.format(i))

# %%
def get_peaks(shift, lfc, n):
    peaks = np.empty(0)
    current = shift
    for i in range(0, n):
        peaks = np.append(peaks, current)
        current += lfc.dWl
    return peaks
    
def pred_error(y, pred_y, solution, prediction):
    lse = np.mean(np.abs(y - pred_y))
    error = np.abs(solution - prediction) / solution * 3e8
    return lse, error
    
def guess_min(x, y):
    guess_x = x[y > 2000]
    guess_y = y[y > 2000]
    max_idx = signal.argrelextrema(guess_y, np.greater, order=10)
    guess_max_x = guess_x[max_idx]
    guess_max_y = guess_y[max_idx]
    guess_x = guess_max_x[0]
    guess_y = guess_max_y[0]
    return guess_x, guess_y

# %%
def find_lfc_peaks(sgraph, lfc, orderId):
    lfc_peaks = lfc.getPeaks()
    
    print('Solution is: {}pix or {}nm'.format(sgraph.wl_to_pix(lfc.minWl), lfc.minWl))

    order_map, obs = sgraph.observe([lfc.simulate()])
    
    bottom = False
    top = False
    mid = False
    orders = []
    order_ranges = []
    # Select relevant orders
    if orderId == 0: # If first order in spectrum
        bottom = True
        orders.append(obs[0])
        order_ranges.append(order_map[0])
        if len(obs) > 1:
            orders.append(obs[1])
            order_ranges.append(order_map[1])
    elif orderId == len(obs) - 1: # else if last
        top = True
        orders.append(obs[-1])
        order_ranges.append(order_map[-1])
        if len(obs) > 1:
            orders.append(obs[-2])
            order_ranges.append(order_map[-2])
    else: # else middle order
        mid = True
        orders.append(obs[orderId - 1])
        order_ranges.append(order_map[orderId - 1])
        orders.append(obs[orderId])
        order_ranges.append(order_map[orderId])
        orders.append(obs[orderId + 1])
        order_ranges.append(order_map[orderId + 1])
        
    # Swap ranges to pixel space
    # Temporary: For now just paste them together
    new_ranges = []
    for i in range(0, len(order_ranges)):
        new_ranges.append([i * sgraph.xres, ((i + 1) * sgraph.xres) - 1])
    order_ranges = new_ranges
        
    ss_xres = 5 * sgraph.xres
    ss_xs = np.empty((len(orders), ss_xres))
    ss_ys = np.empty((len(orders), ss_xres))
    prev_range = None
    # Interpolate selected orders
    for i in range(0, len(orders)):
        order = orders[i]
        order_range = order_ranges[i]
        
        x = np.linspace(order_range[0], order_range[1], sgraph.xres)
        spl = interpolate.UnivariateSpline(x, order, k=3)
        # This is the tricky part. I need the 'distance' between orders, so that I can
        # align them in pixel space correctly. For now, I am assuming that they are adjacent
        ss_x = np.linspace(order_range[0], order_range[1], ss_xres, dtype=np.float64)
        ss_y = spl(ss_x)
        ss_y[ss_y <= 0.0] = 1e-15
        
        ss_xs[i] = ss_x
        ss_ys[i] = ss_y
        
    # Fit on interpolated data
    # Need pred_shift, and pred_shift_wl
    firstRange = order_ranges[0]
    lastRange = order_ranges[-1]
    print(firstRange[0], lastRange[1])
    def per_gauss_fit(wl, shift):
        return per_gauss(wl, sgraph.sigma * sgraph.fac, firstRange[0] + shift, lastRange[0] + shift, 
                         lfc.dWl * sgraph.fac, lfc.intensity)
    
    def err_func(shift):
        err = 0.0
        # Fit the same per_gauss on each order
        for i in range(0, len(ss_xs)):
            err += np.mean(np.abs(per_gauss_fit(ss_xs[i], shift) - ss_ys[i]))
        return err
        
    guess_x, guess_y = guess_min(ss_xs[0], ss_ys[0])
    print('Initial guess for shift is: {}pix or {}nm'.format(np.asarray([guess_x]), sgraph.pix_to_wl(guess_x)))
#     result = optimize.minimize(err_func, guess_x, method='L-BFGS-B', 
#                       options={'ftol':1e-12, 'gtol':1e-12, 'maxiter':20000*(len(ss_x) + 1), 'maxcor': 100000})
#     result = optimize.minimize(err_func, guess_x, method='L-BFGS-B', 
#                       options={'ftol':1e-20, 'gtol':1e-20, 'maxiter':20000*(len(ss_x) + 1), 'disp':True, 
#                                'eps':np.finfo(np.float64).eps, 'maxls':1000000, 'maxfun':10000000, 'maxcor':10})
    result = optimize.minimize(err_func, guess_x, method='L-BFGS-B')
    nfev = result.nfev
    pred_shift = result.x
    pred_shift_wl = sgraph.pix_to_wl(pred_shift)
    
    y_preds = np.asarray([per_gauss_fit(ss_x, pred_shift) for ss_x in ss_xs])
    
    print('Predicted shift is: {}pix or {}nm'.format(np.asarray([pred_shift]), pred_shift_wl))
    print('Number of calls: {}'.format(nfev))
    
#     pred_peaks = get_peaks(pred_shift_wl, lfc, len(lfc_peaks))
    
#     print(lfc_peaks[0:3], lfc_peaks[-3:])
#     print(pred_peaks[0:3], pred_peaks[-3:])
    
#     lse, error = pred_error(ss_y, y_pred, lfc.minWl, pred_shift_wl)
    error = np.abs(lfc.minWl - pred_shift_wl) / lfc.minWl * 3e8
#     print('Least squares error is {}'.format(lse))
    print('Error is: {}m/s'.format(error))
    
#     plot_spectrum(ss_xs, ss_ys, y_preds, guess_x, sgraph.fac, sgraph.wl_to_pix(lfc.minWl))
    
    return error

# %%
def find_lfc_peaks2(sgraph, lfc, orderId):
    lfc_peaks = lfc.getPeaks()
    
    print('Solution is: {}pix or {}nm'.format(sgraph.wl_to_pix(lfc.minWl), lfc.minWl))

    order_map, obs = sgraph.observe([lfc.simulate()])
    
    bottom = False
    top = False
    mid = False
    orders = []
    order_ranges = []
    # Select relevant orders
    if orderId == 0: # If first order in spectrum
        bottom = True
        orders.append(obs[0])
        order_ranges.append(order_map[0])
        if len(obs) > 1:
            orders.append(obs[1])
            order_ranges.append(order_map[1])
    elif orderId == len(obs) - 1: # else if last
        top = True
        orders.append(obs[-1])
        order_ranges.append(order_map[-1])
        if len(obs) > 1:
            orders.append(obs[-2])
            order_ranges.append(order_map[-2])
    else: # else middle order
        mid = True
        orders.append(obs[orderId - 1])
        order_ranges.append(order_map[orderId - 1])
        orders.append(obs[orderId])
        order_ranges.append(order_map[orderId])
        orders.append(obs[orderId + 1])
        order_ranges.append(order_map[orderId + 1])
        
    # Swap ranges to pixel space
    # Temporary: For now just paste them together
    new_ranges = []
    for i in range(0, len(order_ranges)):
        new_ranges.append([i * sgraph.xres, ((i + 1) * sgraph.xres) - 1])
    order_ranges = new_ranges
        
    ss_xres = 5 * sgraph.xres
    ss_xs = np.empty((len(orders), ss_xres))
    ss_ys = np.empty((len(orders), ss_xres))
    prev_range = None
    # Interpolate selected orders
    for i in range(0, len(orders)):
        order = orders[i]
        order_range = order_ranges[i]
        
        x = np.linspace(order_range[0], order_range[1], sgraph.xres)
        spl = interpolate.UnivariateSpline(x, order, k=3)
        # This is the tricky part. I need the 'distance' between orders, so that I can
        # align them in pixel space correctly. For now, I am assuming that they are adjacent
        ss_x = np.linspace(order_range[0], order_range[1], ss_xres, dtype=np.float64)
        ss_y = spl(ss_x)
        ss_y[ss_y <= 0.0] = 1e-15
        
        ss_xs[i] = ss_x
        ss_ys[i] = ss_y
        
    # Fit on interpolated data
    # Need pred_shift, and pred_shift_wl
    firstRange = order_ranges[0]
    lastRange = order_ranges[-1]
    print(firstRange[0], lastRange[1])
    def per_gauss_fit(wl, shift):
#         def per_gauss(wl, sigma, minWl, maxWl, period, amplitude):
        return per_gauss(wl, sgraph.sigma * sgraph.fac, firstRange[0] + shift, lastRange[1] + shift, 
                         lfc.dWl * sgraph.fac, lfc.intensity)
    
    def err_func(shift):
        err = 0.0
        # Fit the same per_gauss on each order
        for i in range(0, len(ss_xs)):
            err += np.mean(np.abs(per_gauss_fit(ss_xs[i], shift) - ss_ys[i]))
        return err
        
    guess_x, guess_y = guess_min(ss_xs[0], ss_ys[0])
    print('Initial guess for shift is: {}pix or {}nm'.format(np.asarray([guess_x]), sgraph.pix_to_wl(guess_x)))
    
    # Paste orders together
    all_ss_y = np.concatenate(ss_ys)
    all_ss_x = np.linspace(0, 12000, 3 * 5 * sgraph.xres, endpoint=False)
    gmod = lmfit.Model(per_gauss_fit)
    result = gmod.fit(all_ss_y, wl=all_ss_x, shift=guess_x, method='lbfgsb', 
                      options={'ftol':1e-20, 'gtol':1e-20, 'maxiter':20000*(len(ss_x) + 1), 'factr':1.0, 'disp':True, 
                               'eps':np.finfo(np.float64).eps, 'maxls':100, 'maxfun':100000, 'maxcor':100})
    pred_shift = result.params['shift'].value
    all_y_pred = result.best_fit
    nfev = result.nfev
    
    pred_shift_wl = sgraph.pix_to_wl(pred_shift)
    
    print('Predicted shift is: {}pix or {}nm'.format(np.asarray([pred_shift]), pred_shift_wl))
    print('Number of calls: {}'.format(nfev))
  
    lse, error = pred_error(all_ss_y, all_y_pred, lfc.minWl, pred_shift_wl)
    print('Least squares error is {}'.format(lse))
    print('Error is: {}m/s'.format(error))
    
    plt.scatter(all_ss_x, all_ss_y, color='blue')
    plt.plot(all_ss_x, all_y_pred, color='red')
    plt.axvline(guess_x, color='turquoise')
#     plt.xlim(sgraph.wl_to_pix(lfc.minWl - 3 * lfc.dWl), sgraph.wl_to_pix(lfc.minWl + 12 * lfc.dWl))
    plt.xlim(7000, 7150)
    fig = plt.show()
    
    return error

# %%
rand = np.random.random(1)[0]
# def __init__(self, xres, nOrders, orderSize, minWl, bgrNoiseMu, bgrNoiseSD, fwhm, precision):
sgraph = Spectrograph(4000, 80, 10.0, 399.0, 1000.0, 300.0, 0.0075, 1.0)
# def __init__(self, intensity, minWl, maxWl, dWl):
lfc = LFC(250000, 400 + rand, 430 + rand, 0.03)

# %%
# %%time
error = find_lfc_peaks2(sgraph, lfc, 1)
# Out:
# Solution is: 427.440181625pix or 400.068600454nm
# (0, 11999)
# Initial guess for shift is: [ 427.514475723786177]pix or 400.068786189nm
#  - Adding parameter "shift"
# Predicted shift is: [ 427.955522308226023]pix or 400.069888806nm

# %%
# %%time
# Make a plot of error to SNR
x = []
y = []
nTests = 10
intenStep = 25000
# nTests = 2
# intenStep = 300000
for intensity in range(20000, 500000, intenStep):
    sgraph = Spectrograph(4000, 80, 10.0, 399.0, 1000.0, 300.0, 0.0075, 1.0)
    lfc = LFC(intensity, 400 + rand, 430 + rand, 0.03)
    # Run 10 tests with each
    x.append(intensity)
    newY = []
    for i in range(0, nTests):
        newY += find_lfc_peaks(sgraph, lfc, 1)
#         newY += np.random.random(1)[0]
    newY = newY / nTests
    y.append(newY)
x = np.asarray(x)
y = np.asarray(y)
plt.plot(x,y)
plt.show()
# Out:
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891321736819009]]pix or [ 400.869728304342061]nm
# Number of calls: 40
# Error is: [ 2.176395347503126]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.89438408119895]]pix or [ 400.869735960203002]nm
# Number of calls: 56
# Error is: [ 7.905833458494635]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.892677131072219]]pix or [ 400.869731692827656]nm
# Number of calls: 66
# Error is: [ 4.712245810050512]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.887646540564333]]pix or [ 400.869719116351405]nm
# Number of calls: 32
# Error is: [ 4.699646973143943]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.901050050365711]]pix or [ 400.869752625125898]nm
# Number of calls: 70
# Error is: [ 20.377408516501898]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.887961882539344]]pix or [ 400.869719904706358]nm
# Number of calls: 58
# Error is: [ 4.109663567366593]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.887861374302133]]pix or [ 400.869719653435766]nm
# Number of calls: 48
# Error is: [ 4.297707644509538]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.893180133776241]]pix or [ 400.869732950334424]nm
# Number of calls: 54
# Error is: [ 5.653329674079718]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.886780896924392]]pix or [ 400.8697169522423]nm
# Number of calls: 74
# Error is: [ 6.319207370063022]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.89108144573288]]pix or [ 400.86972770361433]nm
# Number of calls: 56
# Error is: [ 1.726827051910027]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.892258488082916]]pix or [ 400.869730646220205]nm
# Number of calls: 30
# Error is: [ 3.92899325811196]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891366157760672]]pix or [ 400.869728415394377]nm
# Number of calls: 54
# Error is: [ 2.259503880339765]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.889055640623155]]pix or [ 400.869722639101553]nm
# Number of calls: 40
# Error is: [ 2.063316570545855]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891305574290641]]pix or [ 400.869728263935713]nm
# Number of calls: 38
# Error is: [ 2.146156335228446]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.889247650056177]]pix or [ 400.869723119125126]nm
# Number of calls: 58
# Error is: [ 1.704079983834508]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.889717174793873]]pix or [ 400.869724292937008]nm
# Number of calls: 60
# Error is: [ 0.825631095998044]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.889454654096994]]pix or [ 400.869723636635229]nm
# Number of calls: 34
# Error is: [ 1.316789498017343]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.889448996768465]]pix or [ 400.869723622491904]nm
# Number of calls: 50
# Error is: [ 1.327373977590814]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.893479931456568]]pix or [ 400.869733699828657]nm
# Number of calls: 38
# Error is: [ 6.214230774590419]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.887064866398305]]pix or [ 400.869717662166011]nm
# Number of calls: 42
# Error is: [ 5.787919772656831]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.89032890807573]]pix or [ 400.869725822270198]nm
# Number of calls: 46
# Error is: [ 0.318880269897664]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891633299838759]]pix or [ 400.869729083249581]nm
# Number of calls: 38
# Error is: [ 2.759308551322409]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891999236864308]]pix or [ 400.869729998092168]nm
# Number of calls: 34
# Error is: [ 3.443951862731359]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 0.3999199959998]pix or 399.0009998nm
# Predicted shift is: [[ 3.889065164125995]]pix or [ 399.009722662910292]nm
# Number of calls: 44
# Error is: [ 1391975.458927619736642]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891206587209012]]pix or [ 400.869728016468002]nm
# Number of calls: 60
# Error is: [ 1.960958231221622]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.889248592344416]]pix or [ 400.869723121480888]nm
# Number of calls: 38
# Error is: [ 1.70231699576736]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.89163750706814]]pix or [ 400.86972909376766]nm
# Number of calls: 50
# Error is: [ 2.767179995474446]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891398841576461]]pix or [ 400.869728497103949]nm
# Number of calls: 30
# Error is: [ 2.320653102093079]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.892296000608894]]pix or [ 400.869730740001501]nm
# Number of calls: 20
# Error is: [ 3.999176629175029]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.890203610814865]]pix or [ 400.869725509027035]nm
# Number of calls: 42
# Error is: [ 0.084457606035333]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.892094691736247]]pix or [ 400.869730236729367]nm
# Number of calls: 36
# Error is: [ 3.62254145214572]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.890349932011304]]pix or [ 400.86972587483001]nm
# Number of calls: 34
# Error is: [ 0.35821460410089]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891468194108597]]pix or [ 400.869728670485244]nm
# Number of calls: 62
# Error is: [ 2.450406947879854]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.892251006945571]]pix or [ 400.869730627517356]nm
# Number of calls: 38
# Error is: [ 3.914996554547896]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.890680401172744]]pix or [ 400.869726701002946]nm
# Number of calls: 30
# Error is: [ 0.976499960124649]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891079371017099]]pix or [ 400.869727698427539]nm
# Number of calls: 34
# Error is: [ 1.722945398261326]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891641749364908]]pix or [ 400.869729104373391]nm
# Number of calls: 54
# Error is: [ 2.77511703641242]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891174495272821]]pix or [ 400.869727936238178]nm
# Number of calls: 56
# Error is: [ 1.900916412536716]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891814309441543]]pix or [ 400.869729535773615]nm
# Number of calls: 46
# Error is: [ 3.097965231218109]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891500922157775]]pix or [ 400.869728752305377]nm
# Number of calls: 44
# Error is: [ 2.51163891006679]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891677226483921]]pix or [ 400.869729193066235]nm
# Number of calls: 20
# Error is: [ 2.84149234814564]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891209146697747]]pix or [ 400.869728022866752]nm
# Number of calls: 44
# Error is: [ 1.965746881675083]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891760380889423]]pix or [ 400.869729400952224]nm
# Number of calls: 28
# Error is: [ 2.997068568654419]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891345284727208]]pix or [ 400.869728363211834]nm
# Number of calls: 54
# Error is: [ 2.220451884572503]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891774271243435]]pix or [ 400.869729435678096]nm
# Number of calls: 40
# Error is: [ 3.023056466783736]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891122116416454]]pix or [ 400.869727805291063]nm
# Number of calls: 60
# Error is: [ 1.802919153435436]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.89059975704231]]pix or [ 400.869726499392584]nm
# Number of calls: 24
# Error is: [ 0.825620248280526]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891511784329168]]pix or [ 400.869728779460843]nm
# Number of calls: 24
# Error is: [ 2.531961321846595]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.892352117015434]]pix or [ 400.869730880292536]nm
# Number of calls: 42
# Error is: [ 4.104166624769271]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891555216333586]]pix or [ 400.869728888040811]nm
# Number of calls: 46
# Error is: [ 2.613219616935181]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891861734338818]]pix or [ 400.869729654335856]nm
# Number of calls: 20
# Error is: [ 3.186693987771162]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891758520573035]]pix or [ 400.869729396301409]nm
# Number of calls: 40
# Error is: [ 2.993588025313494]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891355278769197]]pix or [ 400.869728388196904]nm
# Number of calls: 48
# Error is: [ 2.239150031449191]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891183684849921]]pix or [ 400.869727959212128]nm
# Number of calls: 38
# Error is: [ 1.918109491782786]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 0.3999199959998]pix or 399.0009998nm
# Predicted shift is: [[ 3.891491761738951]]pix or [ 399.009728729404344]nm
# Number of calls: 44
# Error is: [ 1391970.918928462080657]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891807272325536]]pix or [ 400.869729518180804]nm
# Number of calls: 52
# Error is: [ 3.084799250115626]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 0.3999199959998]pix or 399.0009998nm
# Predicted shift is: [[ 3.891250887543406]]pix or [ 399.009728127218864]nm
# Number of calls: 50
# Error is: [ 1391971.36958769755438]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891087382398268]]pix or [ 400.869727718455977]nm
# Number of calls: 48
# Error is: [ 1.737934136227481]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.892025704792218]]pix or [ 400.869730064262001]nm
# Number of calls: 56
# Error is: [ 3.493471565583509]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.89146794027954]]pix or [ 400.869728669850701]nm
# Number of calls: 20
# Error is: [ 2.449932073092952]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891688816962869]]pix or [ 400.869729222042395]nm
# Number of calls: 48
# Error is: [ 2.863177318325917]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891299627392186]]pix or [ 400.869728249068487]nm
# Number of calls: 36
# Error is: [ 2.135030107880076]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891730020988234]]pix or [ 400.869729325052447]nm
# Number of calls: 36
# Error is: [ 2.940267239702762]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891825821417797]]pix or [ 400.869729564553552]nm
# Number of calls: 38
# Error is: [ 3.119503353081231]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891988303582821]]pix or [ 400.869729970758954]nm
# Number of calls: 20
# Error is: [ 3.423496428156728]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891332606244305]]pix or [ 400.869728331515603]nm
# Number of calls: 40
# Error is: [ 2.196731287024777]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891754157080186]]pix or [ 400.869729385392702]nm
# Number of calls: 20
# Error is: [ 2.985424245809349]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891319489431908]]pix or [ 400.869728298723601]nm
# Number of calls: 34
# Error is: [ 2.172190644572714]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.89193781143274]]pix or [ 400.869729844528592]nm
# Number of calls: 46
# Error is: [ 3.329029058876066]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891528243340758]]pix or [ 400.869728820608373]nm
# Number of calls: 34
# Error is: [ 2.562755014077058]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891583937802125]]pix or [ 400.869728959844508]nm
# Number of calls: 24
# Error is: [ 2.66695555107636]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.8914840128582]]pix or [ 400.86972871003212]nm
# Number of calls: 48
# Error is: [ 2.480002754315785]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891542419279631]]pix or [ 400.869728856048198]nm
# Number of calls: 40
# Error is: [ 2.589277215469251]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891223309295697]]pix or [ 400.869728058273267]nm
# Number of calls: 60
# Error is: [ 1.992244154587018]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891528831432765]]pix or [ 400.869728822078571]nm
# Number of calls: 18
# Error is: [ 2.563855270413924]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891461686402977]]pix or [ 400.869728654216033]nm
# Number of calls: 24
# Error is: [ 2.438231512277059]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891577487768927]]pix or [ 400.869728943719394]nm
# Number of calls: 42
# Error is: [ 2.654887954547721]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891516109531949]]pix or [ 400.869728790273825]nm
# Number of calls: 38
# Error is: [ 2.54005346387505]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891461676563836]]pix or [ 400.86972865419142]nm
# Number of calls: 36
# Error is: [ 2.438213092427312]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.8912143942988]]pix or [ 400.869728035985759]nm
# Number of calls: 42
# Error is: [ 1.975564789210573]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891490337920459]]pix or [ 400.869728725844823]nm
# Number of calls: 28
# Error is: [ 2.491836550626847]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891738143912335]]pix or [ 400.869729345359758]nm
# Number of calls: 20
# Error is: [ 2.955464679245961]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.89108830689463]]pix or [ 400.86972772076723]nm
# Number of calls: 26
# Error is: [ 1.739663815420837]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891659436770965]]pix or [ 400.869729148591944]nm
# Number of calls: 36
# Error is: [ 2.808208998394488]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 0.3999199959998]pix or 399.0009998nm
# Predicted shift is: [[ 3.891501086184809]]pix or [ 399.009728752715489]nm
# Number of calls: 36
# Error is: [ 1391970.901483034947887]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891615365088228]]pix or [ 400.869729038412743]nm
# Number of calls: 50
# Error is: [ 2.725753881013087]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891358401050411]]pix or [ 400.869728396002643]nm
# Number of calls: 38
# Error is: [ 2.244991633683122]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891533340814021]]pix or [ 400.869728833352042]nm
# Number of calls: 28
# Error is: [ 2.572292029538921]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 0.3999199959998]pix or 399.0009998nm
# Predicted shift is: [[ 3.891527292940464]]pix or [ 399.009728818232361]nm
# Number of calls: 66
# Error is: [ 1391970.852451990125701]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891571449992398]]pix or [ 400.869728928624966]nm
# Number of calls: 32
# Error is: [ 2.643591694544756]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891295668590601]]pix or [ 400.869728239171479]nm
# Number of calls: 26
# Error is: [ 2.127623456518659]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891568759529605]]pix or [ 400.869728921898798]nm
# Number of calls: 22
# Error is: [ 2.638558013295581]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891262444858171]]pix or [ 400.86972815611216]nm
# Number of calls: 20
# Error is: [ 2.065464120834055]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891440922252173]]pix or [ 400.869728602305656]nm
# Number of calls: 42
# Error is: [ 2.399383198358735]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891322889488833]]pix or [ 400.869728307223738]nm
# Number of calls: 32
# Error is: [ 2.17855191628589]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891484112361468]]pix or [ 400.869728710280924]nm
# Number of calls: 44
# Error is: [ 2.480188952196486]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891378773437509]]pix or [ 400.869728446933607]nm
# Number of calls: 48
# Error is: [ 2.28310698221774]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891315998185178]]pix or [ 400.869728289995464]nm
# Number of calls: 26
# Error is: [ 2.165658744643983]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.89144048693197]]pix or [ 400.869728601217332]nm
# Number of calls: 18
# Error is: [ 2.398568726203397]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891371334028804]]pix or [ 400.869728428335065]nm
# Number of calls: 42
# Error is: [ 2.269188339679742]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891524346095594]]pix or [ 400.86972881086524]nm
# Number of calls: 32
# Error is: [ 2.555463518681613]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891184753434459]]pix or [ 400.869727961883598]nm
# Number of calls: 30
# Error is: [ 1.920108747391496]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891412905553466]]pix or [ 400.869728532263878]nm
# Number of calls: 24
# Error is: [ 2.346965836186991]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891214414428418]]pix or [ 400.869728036036065]nm
# Number of calls: 42
# Error is: [ 1.975602437171373]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891170392781987]]pix or [ 400.869727925981977]nm
# Number of calls: 18
# Error is: [ 1.893240950481181]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891443161728148]]pix or [ 400.869728607904335]nm
# Number of calls: 34
# Error is: [ 2.403573097345238]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891247315828082]]pix or [ 400.869728118289572]nm
# Number of calls: 38
# Error is: [ 2.037158724842081]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.89105131347651]]pix or [ 400.86972762828367]nm
# Number of calls: 22
# Error is: [ 1.670451634126197]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891422317273168]]pix or [ 400.869728555793188]nm
# Number of calls: 30
# Error is: [ 2.364574531904263]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891176580724959]]pix or [ 400.869727941451799]nm
# Number of calls: 18
# Error is: [ 1.904818145097843]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891068952651381]]pix or [ 400.8697276723816]nm
# Number of calls: 46
# Error is: [ 1.703453326082483]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891254607237897]]pix or [ 400.86972813651812]nm
# Number of calls: 48
# Error is: [ 2.050800474072908]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891364923174365]]pix or [ 400.86972841230795]nm
# Number of calls: 40
# Error is: [ 2.257194082229542]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891526975133388]]pix or [ 400.869728817437817]nm
# Number of calls: 42
# Error is: [ 2.56038225666516]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891114799394131]]pix or [ 400.86972778699851]nm
# Number of calls: 18
# Error is: [ 1.789229504087253]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891032788320899]]pix or [ 400.869727581970778]nm
# Number of calls: 20
# Error is: [ 1.635792325852933]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891237015402453]]pix or [ 400.86972809253848]nm
# Number of calls: 38
# Error is: [ 2.017887307999587]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891314395595373]]pix or [ 400.86972828598897]nm
# Number of calls: 48
# Error is: [ 2.162660392981776]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891220377502464]]pix or [ 400.869728050943763]nm
# Number of calls: 26
# Error is: [ 1.986758953048658]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891042242527305]]pix or [ 400.869727605606329]nm
# Number of calls: 38
# Error is: [ 1.653480528958606]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.89129711506223]]pix or [ 400.86972824278763]nm
# Number of calls: 44
# Error is: [ 2.1303296855291]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891108959700659]]pix or [ 400.869727772399244]nm
# Number of calls: 42
# Error is: [ 1.778303810622736]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891163325382877]]pix or [ 400.86972790831345]nm
# Number of calls: 32
# Error is: [ 1.88001830600719]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891135904041221]]pix or [ 400.869727839760117]nm
# Number of calls: 42
# Error is: [ 1.828714855534365]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.890920404967915]]pix or [ 400.869727301012404]nm
# Number of calls: 38
# Error is: [ 1.425530719409651]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891115117583126]]pix or [ 400.869727787793977]nm
# Number of calls: 24
# Error is: [ 1.789824809808645]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.89114705726854]]pix or [ 400.869727867643178]nm
# Number of calls: 46
# Error is: [ 1.849581780193534]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891202164574452]]pix or [ 400.869728005411446]nm
# Number of calls: 52
# Error is: [ 1.952683804998787]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891174423323832]]pix or [ 400.869727936058325]nm
# Number of calls: 32
# Error is: [ 1.900781815759348]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891136937480383]]pix or [ 400.869727842343707]nm
# Number of calls: 34
# Error is: [ 1.830648344196865]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.89114157416941]]pix or [ 400.869727853935444]nm
# Number of calls: 32
# Error is: [ 1.839323285166514]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891089542570285]]pix or [ 400.869727723856442]nm
# Number of calls: 18
# Error is: [ 1.741975697994426]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.89111314649233]]pix or [ 400.869727782866221]nm
# Number of calls: 20
# Error is: [ 1.786137011253012]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891113782004709]]pix or [ 400.869727784454994]nm
# Number of calls: 34
# Error is: [ 1.787326006173187]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.890945436824381]]pix or [ 400.869727363592062]nm
# Number of calls: 20
# Error is: [ 1.472363634062756]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891325664676856]]pix or [ 400.869728314161705]nm
# Number of calls: 46
# Error is: [ 2.183744101831042]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891039772391082]]pix or [ 400.869727599430973]nm
# Number of calls: 40
# Error is: [ 1.648859060975137]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.89106334808389]]pix or [ 400.869727658370209]nm
# Number of calls: 18
# Error is: [ 1.692967582008466]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891062990940554]]pix or [ 400.86972765747737]nm
# Number of calls: 32
# Error is: [ 1.69229940514939]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891054644605788]]pix or [ 400.869727636611515]nm
# Number of calls: 40
# Error is: [ 1.676683966891141]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.890929985306798]]pix or [ 400.869727324963264]nm
# Number of calls: 36
# Error is: [ 1.443454892276405]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891133477635549]]pix or [ 400.869727833694071]nm
# Number of calls: 34
# Error is: [ 1.824175192103007]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.89096805241627]]pix or [ 400.869727420131028]nm
# Number of calls: 20
# Error is: [ 1.514675858155144]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891101797773558]]pix or [ 400.86972775449442]nm
# Number of calls: 32
# Error is: [ 1.764904327083157]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891038523752172]]pix or [ 400.86972759630936]nm
# Number of calls: 48
# Error is: [ 1.646522930562389]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.890986850525451]]pix or [ 400.869727467126324]nm
# Number of calls: 58
# Error is: [ 1.549845859953156]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891024336496457]]pix or [ 400.869727560841227]nm
# Number of calls: 22
# Error is: [ 1.619979544215983]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891079377753726]]pix or [ 400.869727698444365]nm
# Number of calls: 30
# Error is: [ 1.722957990121661]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.89103477422384]]pix or [ 400.869727586935539]nm
# Number of calls: 24
# Error is: [ 1.63950781799329]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.890937052674644]]pix or [ 400.869727342631677]nm
# Number of calls: 20
# Error is: [ 1.456677451670259]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.890732760884589]]pix or [ 400.869726831902199]nm
# Number of calls: 34
# Error is: [ 1.074461400488083]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.890924112829566]]pix or [ 400.869727310282087]nm
# Number of calls: 40
# Error is: [ 1.432467898572891]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891148677550404]]pix or [ 400.869727871693897]nm
# Number of calls: 38
# Error is: [ 1.85261322802919]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.890985152033068]]pix or [ 400.869727462880064]nm
# Number of calls: 40
# Error is: [ 1.546668074281171]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.890892921715249]]pix or [ 400.869727232304285]nm
# Number of calls: 36
# Error is: [ 1.374111432329755]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.890922456979069]]pix or [ 400.869727306142465]nm
# Number of calls: 38
# Error is: [ 1.429369918069789]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.89079165614487]]pix or [ 400.869726979140353]nm
# Number of calls: 28
# Error is: [ 1.184650430578539]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.890818542330067]]pix or [ 400.86972704635582]nm
# Number of calls: 24
# Error is: [ 1.234952657994432]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891023385110316]]pix or [ 400.869727558462785]nm
# Number of calls: 38
# Error is: [ 1.618199582661423]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891127197325773]]pix or [ 400.869727817993294]nm
# Number of calls: 24
# Error is: [ 1.812425157187216]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.890720376301374]]pix or [ 400.869726800940725]nm
# Number of calls: 44
# Error is: [ 1.051290675868378]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.890851784429287]]pix or [ 400.869727129461069]nm
# Number of calls: 44
# Error is: [ 1.297146366054545]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.890645708784177]]pix or [ 400.86972661427194]nm
# Number of calls: 30
# Error is: [ 0.911592833782484]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.890781986522484]]pix or [ 400.869726954966325]nm
# Number of calls: 22
# Error is: [ 1.166559245402067]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.890829764057116]]pix or [ 400.86972707441015]nm
# Number of calls: 28
# Error is: [ 1.255947755880595]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.890854451770338]]pix or [ 400.869727136129427]nm
# Number of calls: 36
# Error is: [ 1.302136784053852]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.890799696946715]]pix or [ 400.869726999242346]nm
# Number of calls: 42
# Error is: [ 1.199694215393592]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.890965749036127]]pix or [ 400.869727414372562]nm
# Number of calls: 44
# Error is: [ 1.510366379035524]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.891039966719973]]pix or [ 400.869727599916814]nm
# Number of calls: 58
# Error is: [ 1.649222650942319]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.89095706739522]]pix or [ 400.869727392668494]nm
# Number of calls: 20
# Error is: [ 1.49412364492422]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.890761749448075]]pix or [ 400.869726904373636]nm
# Number of calls: 22
# Error is: [ 1.128697052816286]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.890710012798763]]pix or [ 400.869726775032007]nm
# Number of calls: 26
# Error is: [ 1.031901295415379]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.890727903514289]]pix or [ 400.869726819758796]nm
# Number of calls: 18
# Error is: [ 1.065373608151697]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.890737941534894]]pix or [ 400.869726844853858]nm
# Number of calls: 24
# Error is: [ 1.08415407006132]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.890639840027347]]pix or [ 400.869726599600085]nm
# Number of calls: 34
# Error is: [ 0.900612816650238]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.890629785933925]]pix or [ 400.869726574464835]nm
# Number of calls: 36
# Error is: [ 0.881802278912044]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.890804055820468]]pix or [ 400.86972701013957]nm
# Number of calls: 18
# Error is: [ 1.207849401803861]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.890915655239723]]pix or [ 400.869727289138098]nm
# Number of calls: 46
# Error is: [ 1.416644311758492]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.89075148514894]]pix or [ 400.869726878712868]nm
# Number of calls: 36
# Error is: [ 1.109493232142956]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.890830716194614]]pix or [ 400.869727076790468]nm
# Number of calls: 20
# Error is: [ 1.257729121257422]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.890680199250369]]pix or [ 400.86972670049812]nm
# Number of calls: 24
# Error is: [ 0.976122161774522]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.89060776080953]]pix or [ 400.869726519402036]nm
# Number of calls: 32
# Error is: [ 0.840594777863735]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.89066933369736]]pix or [ 400.869726673334242]nm
# Number of calls: 22
# Error is: [ 0.95579345406455]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.890628280618557]]pix or [ 400.869726570701573]nm
# Number of calls: 40
# Error is: [ 0.878985956203806]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.890653554845699]]pix or [ 400.869726633887126]nm
# Number of calls: 22
# Error is: [ 0.926272305449188]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.890611261888921]]pix or [ 400.869726528154729]nm
# Number of calls: 24
# Error is: [ 0.847145055102146]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.890774238954805]]pix or [ 400.869726935597384]nm
# Number of calls: 22
# Error is: [ 1.152064057312974]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.890904408038296]]pix or [ 400.869727261020103]nm
# Number of calls: 34
# Error is: [ 1.395601568995384]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.890711274656724]]pix or [ 400.869726778186646]nm
# Number of calls: 38
# Error is: [ 1.034262141608042]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.890731566592194]]pix or [ 400.869726828916498]nm
# Number of calls: 24
# Error is: [ 1.072226983379598]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.890697313837791]]pix or [ 400.869726743284616]nm
# Number of calls: 30
# Error is: [ 1.008142411805822]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.89053664204323]]pix or [ 400.869726341605087]nm
# Number of calls: 62
# Error is: [ 0.707536377000248]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.890566750768585]]pix or [ 400.869726416876915]nm
# Number of calls: 38
# Error is: [ 0.763867765812972]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.890622940594199]]pix or [ 400.869726557351498]nm
# Number of calls: 22
# Error is: [ 0.868995123289048]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.890612738902291]]pix or [ 400.869726531847277]nm
# Number of calls: 18
# Error is: [ 0.84990845796492]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.890329033265289]]pix or [ 400.869725822583177]nm
# Number of calls: 18
# Error is: [ 0.319114495515928]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.890633498956618]]pix or [ 400.869726583747365]nm
# Number of calls: 30
# Error is: [ 0.88874907213081]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.890609235873967]]pix or [ 400.869726523089696]nm
# Number of calls: 22
# Error is: [ 0.843354522280601]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.890522758779412]]pix or [ 400.869726306896951]nm
# Number of calls: 26
# Error is: [ 0.681561751372365]m/s
# Solution is: 747.890158469pix or 400.869725396nm
# Initial guess for shift is: [ 747.850392519625984]pix or 400.869625981nm
# Predicted shift is: [[ 747.890660321645214]]pix or [ 400.869726650804125]nm
# Number of calls: 32
# Error is: [ 0.938932527674892]m/s
# /usr/lib/python2.7/site-packages/scipy/interpolate/fitpack2.py:222: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# CPU times: user 4h 57s, sys: 1.54 s, total: 4h 58s
# Wall time: 4h 1min 3s

# %%
y = []
y.append(['1', '2', '3'])
y
# Out:
# [['1', '2', '3']]

# %%
# %store x
# %store y
plt.plot(x,y)
plt.ylim(0, 10)
plt.show()
# Out:
# Stored 'x' (ndarray)
# Stored 'y' (ndarray)

# %% [markdown]
# # Notes
# **For future**:
# - Make a table of effect of increasing the lfc intensity
# - Create plot of jitter to error
# - Resolution = wl of order / (wl to pix ratio) -> 400 / 0.025
# - 80 orders [pix, intens, order]
# - Further away orders are distorted
# - Should use adjacent order
# - Generate plots of SNR to error in cm/s
#     - Moving Sigma from 2 to 4, R from 50,000 to 20,0000
# - Paper submission to PASP
#
# **Open questions**:
# - Spectrograph error distribution: what is a good mean and a mean sdev?
# - Doing least squares: should I weight according to error? For example, know error increases with intensity

# %%
print(y)
# Out:
# [[  6.197826541362301e+00]
#  [  2.757399514691399e+00]
#  [  1.391994815810864e+05]
#  [  2.333124250729437e+00]
#  [  2.492570311509839e+00]
#  [  2.783963392194721e+05]
#  [  2.772760469750668e+00]
#  [  2.433928575820005e+00]
#  [  2.783961935738308e+05]
#  [  2.300629245023427e+00]
#  [  2.107195762322827e+00]
#  [  1.981763915197891e+00]
#  [  1.836641793206022e+00]
#  [  1.752167975150507e+00]
#  [  1.618270186413445e+00]
#  [  1.455991978019249e+00]
#  [  1.283808055133758e+00]
#  [  1.108425718896970e+00]
#  [  1.007906846175394e+00]
#  [  7.870162504847608e-01]]
